# %% [markdown]
# # Final top motif gallery and clustering
#
# This notebook delegates to the script used by SLURM so local and HPC outputs remain identical.

# %%
import subprocess, sys
subprocess.run([sys.executable, '../../../scripts/run_final_top_motif_gallery_and_clustering.py'], check=True)
