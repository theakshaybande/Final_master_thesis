# %% [markdown]
# # Final MP vs LoCoMotif visual comparison
#
# This notebook delegates to the script used by SLURM so local and HPC outputs remain identical.

# %%
import subprocess, sys
subprocess.run([sys.executable, '../../../scripts/run_final_mp_locomotif_visual_comparison.py'], check=True)
