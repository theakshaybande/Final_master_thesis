# %% [markdown]
# # Final visual evidence summary
#
# This notebook delegates to the script used by SLURM so local and HPC outputs remain identical.

# %%
import subprocess, sys
subprocess.run([sys.executable, '../../../scripts/run_final_visual_evidence_summary.py'], check=True)
