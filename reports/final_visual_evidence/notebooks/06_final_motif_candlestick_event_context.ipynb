# %% [markdown]
# # Final motif candlestick and VIX event context
#
# This notebook delegates to the script used by SLURM so local and HPC outputs remain identical.

# %%
import subprocess, sys
subprocess.run([sys.executable, '../../../scripts/run_final_motif_candlestick_event_context.py'], check=True)
