# %% [markdown]
# # 01 Regime Detection Visual Study
#
# ## Objective
# Study, visualize, and document the already-computed quantile and HMM regime labels for the thesis scope: BTCUSDT and ETHUSDT, 15-minute and 1-hour frequencies, 2020-2025.
#
# ## Input files
# - Quantile regime outputs under `results/regimes/quantile`
# - HMM regime outputs under `results/regimes/hmm`
# - Feature files under `final_dataset/features`
#
# ## Output folder
# `reports/study_notebooks`, especially `figures/regime` and `tables`.
#
# ## Thesis relevance
# These figures explain what market regimes were detected and how those labels condition motif discovery. This notebook does not rerun regime detection or modify original result files.
#
# ## Analysis-only safety
# This notebook never imports or calls STUMPY, STUMP/MSTUMP, HMM fitting, LoCoMotif search, or any other expensive experiment algorithm. It only reads saved result files and thesis-scope feature parquet files, then produces derived tables and figures.
#
# **Quantile caveat.** The quantile regime outputs store `rolling_volatility_60` as the actual volatility column across all quantile method identifiers. Therefore, quantile regimes are interpreted as 60-period rolling-volatility regimes with different regime-count granularities rather than as separate 30/60/240 volatility-horizon experiments.

# %%
from pathlib import Path
import sys
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

NOTEBOOK_DIR = Path.cwd() / "HPC workflow" / "HPC_Regime_and_motif_discovery" / "notebooks" / "study"
if NOTEBOOK_DIR.exists() and str(NOTEBOOK_DIR) not in sys.path:
    sys.path.insert(0, str(NOTEBOOK_DIR))

from study_helpers import *

ensure_study_output_dirs()
plt.rcParams.update({
    "figure.figsize": (12, 6),
    "axes.grid": True,
    "grid.alpha": 0.25,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "font.size": 11,
})

print("Project root:", PROJECT_ROOT)
print("Workflow root:", WORKFLOW_ROOT)
print("Study outputs:", REPORT_ROOT)
# Out:
# Project root: /home/i6404275/Final_master_thesis
# Workflow root: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery
# Study outputs: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks

# %% [markdown]
# ## Load Quantile and HMM Thesis-Scope Files

# %%
quantile_dir = result_path("regimes", "quantile")
hmm_dir = result_path("regimes", "hmm")

quantile_files = {
    "labels": resolve_existing_file(quantile_dir, "quantile_regime_labels.parquet"),
    "summary": resolve_existing_file(quantile_dir, "quantile_regime_summary.parquet"),
    "transitions": resolve_existing_file(quantile_dir, "quantile_transition_matrix.parquet"),
}
hmm_files = {
    "labels": resolve_existing_file(hmm_dir, "hmm_regime_labels.parquet"),
    "summary": resolve_existing_file(hmm_dir, "hmm_regime_summary.parquet"),
    "transitions": resolve_existing_file(hmm_dir, "hmm_transition_matrix.parquet"),
    "persistence": resolve_existing_file(hmm_dir, "hmm_persistence_metrics.parquet"),
}

quantile_labels = coerce_timestamp(safe_read_parquet(quantile_files["labels"]))
quantile_summary = safe_read_parquet(quantile_files["summary"])
quantile_transitions = safe_read_parquet(quantile_files["transitions"])
hmm_labels = coerce_timestamp(safe_read_parquet(hmm_files["labels"]))
hmm_summary = safe_read_parquet(hmm_files["summary"])
hmm_transitions = safe_read_parquet(hmm_files["transitions"])
hmm_persistence = safe_read_parquet(hmm_files["persistence"])

file_inventory = pd.DataFrame([
    {"dataset": f"quantile_{k}", "path": str(v), "exists": v.exists()} for k, v in quantile_files.items()
] + [
    {"dataset": f"hmm_{k}", "path": str(v), "exists": v.exists()} for k, v in hmm_files.items()
])
display_table(file_inventory)
save_table(file_inventory, "study_regime_file_inventory")
# Out:
# Loaded quantile_regime_labels.parquet: 73,097,388 rows, 11 columns
# Loaded quantile_regime_summary.parquet: 432 rows, 12 columns
# Loaded quantile_transition_matrix.parquet: 1,203 rows, 7 columns
# Loaded hmm_regime_labels.parquet: 8,121,932 rows, 13 columns
# Loaded hmm_regime_summary.parquet: 62 rows, 12 columns
# Loaded hmm_transition_matrix.parquet: 205 rows, 7 columns
# Loaded hmm_persistence_metrics.parquet: 62 rows, 7 columns
#                 dataset                                               path  \
# 0       quantile_labels  /home/i6404275/Final_master_thesis/HPC workflo...
# 1      quantile_summary  /home/i6404275/Final_master_thesis/HPC workflo...
# 2  quantile_transitions  /home/i6404275/Final_master_thesis/HPC workflo...
# 3            hmm_labels  /home/i6404275/Final_master_thesis/HPC workflo...
# 4           hmm_summary  /home/i6404275/Final_master_thesis/HPC workflo...
# 5       hmm_transitions  /home/i6404275/Final_master_thesis/HPC workflo...
# 6       hmm_persistence  /home/i6404275/Final_master_thesis/HPC workflo...
#
#    exists
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# Saved table: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/tables/study_regime_file_inventory.csv
# PosixPath('/home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/tables/study_regime_file_inventory.csv')

# %% [markdown]
# ## Validate Files, Shapes, Columns, and Date Ranges

# %%
def frame_schema(name, df):
    ts = timestamp_column(df)
    return {
        "name": name,
        "rows": len(df),
        "columns": len(df.columns) if df is not None else 0,
        "timestamp_column": ts,
        "min_timestamp": df[ts].min() if ts and not df.empty else pd.NaT,
        "max_timestamp": df[ts].max() if ts and not df.empty else pd.NaT,
        "useful_columns": useful_columns(df),
    }

schema = pd.DataFrame([
    frame_schema("quantile_labels", quantile_labels),
    frame_schema("quantile_summary", quantile_summary),
    frame_schema("quantile_transitions", quantile_transitions),
    frame_schema("hmm_labels", hmm_labels),
    frame_schema("hmm_summary", hmm_summary),
    frame_schema("hmm_transitions", hmm_transitions),
    frame_schema("hmm_persistence", hmm_persistence),
])
display_table(schema, 20)
save_table(schema, "study_regime_schema_validation")
# Out:
#                    name      rows  columns timestamp_column  \
# 0       quantile_labels  73097388       11        timestamp
# 1      quantile_summary       432       12    min_timestamp
# 2  quantile_transitions      1203        7              NaN
# 3            hmm_labels   8121932       13        timestamp
# 4           hmm_summary        62       12    min_timestamp
# 5       hmm_transitions       205        7              NaN
# 6       hmm_persistence        62        7              NaN
#
#               min_timestamp             max_timestamp  \
# 0 2010-01-04 00:00:00+00:00 2025-12-31 23:59:00+00:00
# 1 2010-01-04 00:00:00+00:00 2020-07-23 00:00:00+00:00
# 2                       NaT                       NaT
# 3 2010-01-04 00:00:00+00:00 2025-12-31 23:59:00+00:00
# 4 2010-01-04 00:00:00+00:00 2020-03-13 02:30:00+00:00
# 5                       NaT                       NaT
# 6                       NaT                       NaT
#
#                                       useful_columns
# 0  asset, frequency, regime_method, regime_label,...
# 1  asset, frequency, regime_method, regime_label,...
# 2  asset, frequency, regime_method, from_regime, ...
# 3  asset, frequency, regime_method, regime_label,...
# 4  asset, frequency, regime_method, regime_label,...
# 5  asset, frequency, regime_method, from_regime, ...
# 6  asset, frequency, regime_method, regime_label,...
# Saved table: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/tables/study_regime_schema_validation.csv
# PosixPath('/home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/tables/study_regime_schema_validation.csv')

# %% [markdown]
# ## Regime Coverage Table

# %%
def coverage_row(df, asset, frequency, method_name):
    scoped = filter_scope(df, asset, frequency)
    ts = timestamp_column(scoped)
    reg = regime_column(scoped)
    method_col = "regime_method" if "regime_method" in scoped.columns else None
    return {
        "asset": asset,
        "frequency": frequency,
        "method": method_name,
        "rows": len(scoped),
        "min_timestamp": scoped[ts].min() if ts and not scoped.empty else pd.NaT,
        "max_timestamp": scoped[ts].max() if ts and not scoped.empty else pd.NaT,
        "regime_methods": ", ".join(sorted(scoped[method_col].dropna().astype(str).unique())) if method_col and not scoped.empty else "",
        "regime_labels": ", ".join(sorted(scoped[reg].dropna().astype(str).unique())) if reg and not scoped.empty else "",
    }

coverage = pd.DataFrame(
    [coverage_row(quantile_labels, asset, frequency, "quantile") for asset in THESIS_SCOPE_ASSETS for frequency in THESIS_SCOPE_FREQUENCIES]
    + [coverage_row(hmm_labels, asset, frequency, "HMM") for asset in THESIS_SCOPE_ASSETS for frequency in THESIS_SCOPE_FREQUENCIES]
)
display_table(coverage, 20)
save_table(coverage, "study_regime_coverage_table")
# Out:
#      asset frequency    method     rows             min_timestamp  \
# 0  BTCUSDT       15m  quantile  1892520 2020-01-01 00:00:00+00:00
# 1  BTCUSDT        1h  quantile   473193 2020-01-01 00:00:00+00:00
# 2  ETHUSDT       15m  quantile  1892520 2020-01-01 00:00:00+00:00
# 3  ETHUSDT        1h  quantile   473193 2020-01-01 00:00:00+00:00
# 4  BTCUSDT       15m       HMM   210280 2020-01-01 00:00:00+00:00
# 5  BTCUSDT        1h       HMM    52577 2020-01-01 00:00:00+00:00
# 6  ETHUSDT       15m       HMM   210280 2020-01-01 00:00:00+00:00
# 7  ETHUSDT        1h       HMM    52577 2020-01-01 00:00:00+00:00
#
#               max_timestamp  \
# 0 2025-12-31 23:45:00+00:00
# 1 2025-12-31 23:00:00+00:00
# 2 2025-12-31 23:45:00+00:00
# 3 2025-12-31 23:00:00+00:00
# 4 2025-12-31 23:45:00+00:00
# 5 2025-12-31 23:00:00+00:00
# 6 2025-12-31 23:45:00+00:00
# 7 2025-12-31 23:00:00+00:00
#
#                                       regime_methods  \
# 0  quantile_2_rolling_240, quantile_2_rolling_30,...
# 1  quantile_2_rolling_240, quantile_2_rolling_30,...
# 2  quantile_2_rolling_240, quantile_2_rolling_30,...
# 3  quantile_2_rolling_240, quantile_2_rolling_30,...
# 4                                       hmm_4_states
# 5                                       hmm_4_states
# 6                                       hmm_4_states
# 7                                       hmm_4_states
#
#                                 regime_labels
# 0  extreme_vol, high_vol, low_vol, medium_vol
# 1  extreme_vol, high_vol, low_vol, medium_vol
# 2  extreme_vol, high_vol, low_vol, medium_vol
# 3  extreme_vol, high_vol, low_vol, medium_vol
# 4  extreme_vol, high_vol, low_vol, medium_vol
# 5  extreme_vol, high_vol, low_vol, medium_vol
# 6  extreme_vol, high_vol, low_vol, medium_vol
# 7  extreme_vol, high_vol, low_vol, medium_vol
# Saved table: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/tables/study_regime_coverage_table.csv
# PosixPath('/home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/tables/study_regime_coverage_table.csv')

# %% [markdown]
# ## Regime Label Counts

# %%
def plot_regime_counts(df, method_name, asset, frequency, filename):
    scoped = filter_scope(df, asset, frequency)
    if method_name.lower() == "quantile":
        selected = choose_quantile_method(scoped)
        if selected and "regime_method" in scoped.columns:
            scoped = scoped[scoped["regime_method"].astype(str) == selected]
            method_title = f"{method_name}: {selected}"
        else:
            method_title = method_name
    else:
        method_title = method_name
    reg = regime_column(scoped)
    if scoped.empty or not reg:
        print(f"No label counts available for {asset} {frequency} {method_name}")
        return
    counts = scoped[reg].astype(str).value_counts().sort_index()
    fig, ax = plt.subplots(figsize=(10, 5))
    counts.plot(kind="bar", ax=ax, color="#4C78A8")
    ax.set_title(f"Regime label counts - {asset} {frequency} {method_title}")
    ax.set_xlabel("Regime label")
    ax.set_ylabel("Rows")
    fig.tight_layout()
    save_fig(fig, filename, FIGURE_DIRS["regime"])
    plt.show()

for asset in ["BTCUSDT", "ETHUSDT"]:
    plot_regime_counts(quantile_labels, "quantile", asset, "15m", f"study_regime_counts_{asset}_15m_quantile")
    plot_regime_counts(hmm_labels, "HMM", asset, "15m", f"study_regime_counts_{asset}_15m_hmm")
# Out:
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_counts_BTCUSDT_15m_quantile.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_counts_BTCUSDT_15m_quantile.pdf
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_counts_BTCUSDT_15m_hmm.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_counts_BTCUSDT_15m_hmm.pdf
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_counts_ETHUSDT_15m_quantile.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_counts_ETHUSDT_15m_quantile.pdf
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_counts_ETHUSDT_15m_hmm.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_counts_ETHUSDT_15m_hmm.pdf

# %% [markdown]
# ## Price and Regime Overlays

# %%
def plot_price_regime_overlay(labels, method_name, asset, frequency, filename, max_points=6000):
    scoped = filter_scope(labels, asset, frequency)
    if method_name.lower() == "quantile":
        selected = choose_quantile_method(scoped)
        if selected and "regime_method" in scoped.columns:
            scoped = scoped[scoped["regime_method"].astype(str) == selected]
    ts = timestamp_column(scoped)
    reg = regime_column(scoped)
    feature = load_feature_data(asset, frequency)
    fts = timestamp_column(feature)
    if scoped.empty or feature.empty or not ts or not fts or not reg or "close" not in feature.columns:
        print(f"Cannot draw overlay for {asset} {frequency} {method_name}: missing labels, timestamps, or close.")
        return
    merged = pd.merge(
        feature[[fts, "close"]].rename(columns={fts: "timestamp"}),
        scoped[[ts, reg]].rename(columns={ts: "timestamp", reg: "regime_label"}),
        on="timestamp",
        how="inner",
    ).dropna(subset=["timestamp", "close", "regime_label"]).sort_values("timestamp")
    if merged.empty:
        print(f"No timestamp overlap for {asset} {frequency} {method_name}")
        return
    if len(merged) > max_points:
        step = int(np.ceil(len(merged) / max_points))
        merged = merged.iloc[::step].copy()
    labels_sorted = sorted(merged["regime_label"].astype(str).unique())
    color_map = {label: plt.cm.tab10(i % 10) for i, label in enumerate(labels_sorted)}
    fig, ax = plt.subplots(figsize=(14, 6))
    ax.plot(merged["timestamp"], merged["close"], color="0.75", linewidth=0.8, label="close")
    for label in labels_sorted:
        part = merged[merged["regime_label"].astype(str) == label]
        ax.scatter(part["timestamp"], part["close"], s=7, color=color_map[label], label=str(label), alpha=0.75)
    ax.set_title(f"{asset} {frequency} close price by {method_name} regime")
    ax.set_xlabel("Timestamp")
    ax.set_ylabel("Close price")
    ax.legend(title="Regime", ncol=min(4, len(labels_sorted)))
    fig.autofmt_xdate()
    fig.tight_layout()
    save_fig(fig, filename, FIGURE_DIRS["regime"])
    plt.show()

for asset in ["BTCUSDT", "ETHUSDT"]:
    plot_price_regime_overlay(quantile_labels, "quantile", asset, "15m", f"study_regime_{asset}_15m_quantile_close_by_regime")
    plot_price_regime_overlay(hmm_labels, "HMM", asset, "15m", f"study_regime_{asset}_15m_hmm_close_by_regime")
# Out:
# Loaded BTCUSDT_15m_features_2020_2025.parquet: 210,280 rows, 19 columns
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_quantile_close_by_regime.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_quantile_close_by_regime.pdf
# Loaded BTCUSDT_15m_features_2020_2025.parquet: 210,280 rows, 19 columns
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_hmm_close_by_regime.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_hmm_close_by_regime.pdf
# Loaded ETHUSDT_15m_features_2020_2025.parquet: 210,280 rows, 19 columns
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_ETHUSDT_15m_quantile_close_by_regime.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_ETHUSDT_15m_quantile_close_by_regime.pdf
# Loaded ETHUSDT_15m_features_2020_2025.parquet: 210,280 rows, 19 columns
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_ETHUSDT_15m_hmm_close_by_regime.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_ETHUSDT_15m_hmm_close_by_regime.pdf

# %% [markdown]
# ### Interpretation
# The overlay figures show where regime labels occur on the observed price path. Dense 15-minute data is sampled only for visualization clarity; the saved regime labels themselves are not changed.

# %% [markdown]
# ## Volatility Distribution by Regime

# %%
def plot_volatility_by_regime(labels, method_name, asset, frequency, filename):
    scoped = filter_scope(labels, asset, frequency)
    if method_name.lower() == "quantile":
        selected = choose_quantile_method(scoped)
        if selected and "regime_method" in scoped.columns:
            scoped = scoped[scoped["regime_method"].astype(str) == selected]
    reg = regime_column(scoped)
    vol_col = next((c for c in ["volatility_value", "rolling_volatility_60", "rolling_vol"] if c in scoped.columns), None)
    if not vol_col:
        feature = load_feature_data(asset, frequency)
        ts = timestamp_column(scoped)
        fts = timestamp_column(feature)
        feature_vol = next((c for c in ["rolling_volatility_60", "rolling_vol"] if c in feature.columns), None)
        if ts and fts and feature_vol and reg:
            scoped = pd.merge(
                scoped[[ts, reg]].rename(columns={ts: "timestamp"}),
                feature[[fts, feature_vol]].rename(columns={fts: "timestamp"}),
                on="timestamp",
                how="inner",
            )
            vol_col = feature_vol
    if scoped.empty or not reg or not vol_col:
        print(f"No volatility column available for {asset} {frequency} {method_name}")
        return
    groups = [g[vol_col].dropna().to_numpy() for _, g in scoped.groupby(reg)]
    labels_order = [str(k) for k, _ in scoped.groupby(reg)]
    if not groups:
        print(f"No volatility observations available for {asset} {frequency} {method_name}")
        return
    fig, ax = plt.subplots(figsize=(11, 5))
    ax.boxplot(groups, labels=labels_order, showfliers=False)
    ax.set_title(f"Volatility distribution by regime - {asset} {frequency} {method_name}")
    ax.set_xlabel("Regime label")
    ax.set_ylabel(vol_col)
    fig.tight_layout()
    save_fig(fig, filename, FIGURE_DIRS["regime"])
    plt.show()

for asset in ["BTCUSDT", "ETHUSDT"]:
    plot_volatility_by_regime(quantile_labels, "quantile", asset, "15m", f"study_regime_{asset}_15m_quantile_volatility_by_regime")
    plot_volatility_by_regime(hmm_labels, "HMM", asset, "15m", f"study_regime_{asset}_15m_hmm_volatility_by_regime")
# Out:
# /tmp/ipykernel_2340816/2889291764.py:31: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(groups, labels=labels_order, showfliers=False)
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_quantile_volatility_by_regime.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_quantile_volatility_by_regime.pdf
# Loaded BTCUSDT_15m_features_2020_2025.parquet: 210,280 rows, 19 columns
# /tmp/ipykernel_2340816/2889291764.py:31: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(groups, labels=labels_order, showfliers=False)
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_hmm_volatility_by_regime.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_hmm_volatility_by_regime.pdf
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_ETHUSDT_15m_quantile_volatility_by_regime.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_ETHUSDT_15m_quantile_volatility_by_regime.pdf
# /tmp/ipykernel_2340816/2889291764.py:31: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(groups, labels=labels_order, showfliers=False)
# Loaded ETHUSDT_15m_features_2020_2025.parquet: 210,280 rows, 19 columns
# /tmp/ipykernel_2340816/2889291764.py:31: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(groups, labels=labels_order, showfliers=False)
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_ETHUSDT_15m_hmm_volatility_by_regime.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_ETHUSDT_15m_hmm_volatility_by_regime.pdf

# %% [markdown]
# ## Transition Heatmaps

# %%
q_method = choose_quantile_method(filter_scope(quantile_labels, "BTCUSDT", "15m"))
q_filters = {"asset": "BTCUSDT", "frequency": "15m"}
if q_method:
    q_filters["regime_method"] = q_method
plot_heatmap_from_table(
    quantile_transitions,
    "BTCUSDT 15m quantile transition probabilities",
    "study_regime_BTCUSDT_15m_quantile_transition_heatmap",
    FIGURE_DIRS["regime"],
    q_filters,
)
plot_heatmap_from_table(
    hmm_transitions,
    "BTCUSDT 15m HMM transition probabilities",
    "study_regime_BTCUSDT_15m_hmm_transition_heatmap",
    FIGURE_DIRS["regime"],
    {"asset": "BTCUSDT", "frequency": "15m"},
)
# Out:
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_quantile_transition_heatmap.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_quantile_transition_heatmap.pdf
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_hmm_transition_heatmap.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_BTCUSDT_15m_hmm_transition_heatmap.pdf
# to_regime    extreme_vol  high_vol   low_vol  medium_vol
# from_regime
# extreme_vol     0.000000  1.000000  0.000000    0.000000
# high_vol        0.000043  0.493517  0.035365    0.471075
# low_vol         0.000000  0.023289  0.673593    0.303118
# medium_vol      0.000000  0.106814  0.353453    0.539733

# %% [markdown]
# ## Regime Duration and Persistence

# %%
def segment_durations(labels, method_name):
    rows = []
    if labels is None or labels.empty:
        return pd.DataFrame()
    ts = timestamp_column(labels)
    reg = regime_column(labels)
    if not ts or not reg:
        return pd.DataFrame()
    group_cols = [c for c in ["asset", "frequency", "regime_method"] if c in labels.columns]
    for keys, part in labels.dropna(subset=[ts, reg]).sort_values(ts).groupby(group_cols, dropna=False):
        part = part.sort_values(ts).copy()
        segment_id = (part[reg].astype(str) != part[reg].astype(str).shift()).cumsum()
        for sid, seg in part.groupby(segment_id):
            rec = {col: val for col, val in zip(group_cols, keys if isinstance(keys, tuple) else (keys,))}
            rec.update({
                "method_family": method_name,
                "regime_label": seg[reg].iloc[0],
                "duration_observations": len(seg),
                "start_timestamp": seg[ts].min(),
                "end_timestamp": seg[ts].max(),
            })
            rows.append(rec)
    out = pd.DataFrame(rows)
    if out.empty:
        return out
    freq_minutes = {"15m": 15, "1h": 60}
    out["approx_duration_hours"] = out.apply(
        lambda r: r["duration_observations"] * freq_minutes.get(str(r.get("frequency")), np.nan) / 60,
        axis=1,
    )
    return out

durations = pd.concat([
    segment_durations(quantile_labels, "quantile"),
    segment_durations(hmm_labels, "HMM"),
], ignore_index=True)
display_table(durations, 20)
save_table(durations, "study_regime_segment_durations")

summary_cols = [c for c in ["method_family", "asset", "frequency", "regime_method", "regime_label"] if c in durations.columns]
duration_summary = durations.groupby(summary_cols, dropna=False)["duration_observations"].agg(["count", "mean", "median"]).reset_index() if not durations.empty else pd.DataFrame()
display_table(duration_summary, 30)
save_table(duration_summary, "study_regime_duration_summary")

if not durations.empty:
    focus = durations[durations.get("frequency", "").astype(str).eq("15m")] if "frequency" in durations.columns else durations
    fig, ax = plt.subplots(figsize=(12, 5))
    labels_box = []
    values = []
    for key, part in focus.groupby(["method_family", "regime_label"], dropna=False):
        labels_box.append(" / ".join(map(str, key)))
        values.append(part["duration_observations"].to_numpy())
    if values:
        ax.boxplot(values, labels=labels_box, showfliers=False)
        ax.set_title("Regime segment duration distribution, 15m labels")
        ax.set_ylabel("Consecutive observations")
        ax.tick_params(axis="x", rotation=45)
        fig.tight_layout()
        save_fig(fig, "study_regime_duration_distribution_15m", FIGURE_DIRS["regime"])
        plt.show()
# Out:
#       asset frequency           regime_method method_family regime_label  \
# 0   BTCUSDT       15m  quantile_2_rolling_240      quantile      low_vol
# 1   BTCUSDT       15m  quantile_2_rolling_240      quantile     high_vol
# 2   BTCUSDT       15m  quantile_2_rolling_240      quantile      low_vol
# 3   BTCUSDT       15m  quantile_2_rolling_240      quantile     high_vol
# 4   BTCUSDT       15m  quantile_2_rolling_240      quantile      low_vol
# 5   BTCUSDT       15m  quantile_2_rolling_240      quantile     high_vol
# 6   BTCUSDT       15m  quantile_2_rolling_240      quantile      low_vol
# 7   BTCUSDT       15m  quantile_2_rolling_240      quantile     high_vol
# 8   BTCUSDT       15m  quantile_2_rolling_240      quantile      low_vol
# 9   BTCUSDT       15m  quantile_2_rolling_240      quantile     high_vol
# 10  BTCUSDT       15m  quantile_2_rolling_240      quantile      low_vol
# 11  BTCUSDT       15m  quantile_2_rolling_240      quantile     high_vol
# 12  BTCUSDT       15m  quantile_2_rolling_240      quantile      low_vol
# 13  BTCUSDT       15m  quantile_2_rolling_240      quantile     high_vol
# 14  BTCUSDT       15m  quantile_2_rolling_240      quantile      low_vol
# 15  BTCUSDT       15m  quantile_2_rolling_240      quantile     high_vol
# 16  BTCUSDT       15m  quantile_2_rolling_240      quantile      low_vol
# 17  BTCUSDT       15m  quantile_2_rolling_240      quantile     high_vol
# 18  BTCUSDT       15m  quantile_2_rolling_240      quantile      low_vol
# 19  BTCUSDT       15m  quantile_2_rolling_240      quantile     high_vol
#
#     duration_observations           start_timestamp             end_timestamp  \
# 0                     166 2020-01-01 00:00:00+00:00 2020-01-02 17:15:00+00:00
# 1                       6 2020-01-02 17:30:00+00:00 2020-01-02 18:45:00+00:00
# 2                       5 2020-01-02 19:00:00+00:00 2020-01-02 20:00:00+00:00
# 3                      11 2020-01-02 20:15:00+00:00 2020-01-02 22:45:00+00:00
# 4                       6 2020-01-02 23:00:00+00:00 2020-01-03 00:15:00+00:00
# 5                       1 2020-01-03 00:30:00+00:00 2020-01-03 00:30:00+00:00
# 6                       4 2020-01-03 00:45:00+00:00 2020-01-03 01:30:00+00:00
# 7                     109 2020-01-03 01:45:00+00:00 2020-01-04 04:45:00+00:00
# 8                     268 2020-01-04 05:00:00+00:00 2020-01-06 23:45:00+00:00
# 9                      61 2020-01-07 00:00:00+00:00 2020-01-07 15:00:00+00:00
# 10                      3 2020-01-07 15:15:00+00:00 2020-01-07 15:45:00+00:00
# 11                    186 2020-01-07 16:00:00+00:00 2020-01-09 14:15:00+00:00
# 12                     20 2020-01-09 14:30:00+00:00 2020-01-09 19:15:00+00:00
# 13                     65 2020-01-09 19:30:00+00:00 2020-01-10 11:30:00+00:00
# 14                      3 2020-01-10 11:45:00+00:00 2020-01-10 12:15:00+00:00
# 15                    111 2020-01-10 12:30:00+00:00 2020-01-11 16:00:00+00:00
# 16                      5 2020-01-11 16:15:00+00:00 2020-01-11 17:15:00+00:00
# 17                      2 2020-01-11 17:30:00+00:00 2020-01-11 17:45:00+00:00
# 18                     14 2020-01-11 18:00:00+00:00 2020-01-11 21:15:00+00:00
# 19                     61 2020-01-11 21:30:00+00:00 2020-01-12 12:30:00+00:00
#
#     approx_duration_hours
# 0                   41.50
# 1                    1.50
# 2                    1.25
# 3                    2.75
# 4                    1.50
# 5                    0.25
# 6                    1.00
# 7                   27.25
# 8                   67.00
# 9                   15.25
# 10                   0.75
# 11                  46.50
# 12                   5.00
# 13                  16.25
# 14                   0.75
# 15                  27.75
# 16                   1.25
# 17                   0.50
# 18                   3.50
# 19                  15.25
# Saved table: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/tables/study_regime_segment_durations.csv
#    method_family    asset frequency regime_method regime_label   count  \
# 0            HMM  BTCUSDT       15m  hmm_4_states  extreme_vol       1
# 1            HMM  BTCUSDT       15m  hmm_4_states     high_vol   11758
# 2            HMM  BTCUSDT       15m  hmm_4_states      low_vol   32139
# 3            HMM  BTCUSDT       15m  hmm_4_states   medium_vol   40781
# 4            HMM  BTCUSDT        1d  hmm_4_states  extreme_vol       1
# 5            HMM  BTCUSDT        1d  hmm_4_states     high_vol     290
# 6            HMM  BTCUSDT        1d  hmm_4_states      low_vol     431
# 7            HMM  BTCUSDT        1d  hmm_4_states   medium_vol     532
# 8            HMM  BTCUSDT        1h  hmm_4_states  extreme_vol     547
# 9            HMM  BTCUSDT        1h  hmm_4_states     high_vol    5217
# 10           HMM  BTCUSDT        1h  hmm_4_states      low_vol    8536
# 11           HMM  BTCUSDT        1h  hmm_4_states   medium_vol   11187
# 12           HMM  BTCUSDT        1m  hmm_4_states  extreme_vol   95449
# 13           HMM  BTCUSDT        1m  hmm_4_states     high_vol  425093
# 14           HMM  BTCUSDT        1m  hmm_4_states      low_vol  470770
# 15           HMM  BTCUSDT        1m  hmm_4_states   medium_vol  582966
# 16           HMM  BTCUSDT        5m  hmm_2_states     high_vol   58584
# 17           HMM  BTCUSDT        5m  hmm_2_states      low_vol   58585
# 18           HMM      DAX        1d  hmm_4_states  extreme_vol     180
# 19           HMM      DAX        1d  hmm_4_states     high_vol     761
# 20           HMM      DAX        1d  hmm_4_states      low_vol     743
# 21           HMM      DAX        1d  hmm_4_states   medium_vol     930
# 22           HMM  ETHUSDT       15m  hmm_4_states  extreme_vol       1
# 23           HMM  ETHUSDT       15m  hmm_4_states     high_vol   12578
# 24           HMM  ETHUSDT       15m  hmm_4_states      low_vol   33267
# 25           HMM  ETHUSDT       15m  hmm_4_states   medium_vol   41811
# 26           HMM  ETHUSDT        1d  hmm_4_states  extreme_vol       1
# 27           HMM  ETHUSDT        1d  hmm_4_states     high_vol     250
# 28           HMM  ETHUSDT        1d  hmm_4_states      low_vol     450
# 29           HMM  ETHUSDT        1d  hmm_4_states   medium_vol     485
#
#         mean  median
# 0   1.000000     1.0
# 1   1.974400     1.0
# 2   3.063599     2.0
# 3   2.172654     1.0
# 4   1.000000     1.0
# 5   1.462069     1.0
# 6   1.960557     1.0
# 7   1.733083     1.0
# 8   1.000000     1.0
# 9   1.774966     1.0
# 10  2.496134     1.0
# 11  1.918566     1.0
# 12  2.089860     1.0
# 13  2.284608     1.0
# 14  1.847195     1.0
# 15  1.910755     1.0
# 16  2.370494     1.0
# 17  8.397388     3.0
# 18  2.433333     1.0
# 19  1.431012     1.0
# 20  1.485868     1.0
# 21  1.535484     1.0
# 22  1.000000     1.0
# 23  1.946414     1.0
# 24  2.934409     2.0
# 25  2.108967     1.0
# 26  1.000000     1.0
# 27  1.836000     1.0
# 28  1.928889     1.0
# 29  1.781443     1.0
# Saved table: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/tables/study_regime_duration_summary.csv
# /tmp/ipykernel_2340816/681380400.py:54: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(values, labels=labels_box, showfliers=False)
# Saved figure: /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_duration_distribution_15m.png, /home/i6404275/Final_master_thesis/HPC workflow/HPC_Regime_and_motif_discovery/reports/study_notebooks/figures/regime/study_regime_duration_distribution_15m.pdf

# %% [markdown]
# ## Key findings
# Use the tables and figures above to report which regime files are complete and which labels are available for each thesis-scope asset/frequency pair.
#
# ## Thesis-safe interpretation
# Quantile regimes provide deterministic partitions of observed rolling volatility. HMM regimes provide latent probabilistic regimes inferred from multiple features when the corresponding HMM output files contain labels. Both families are used as alternative market-state labels for conditioned motif discovery.
#
# ## Limitations
# The notebook only reports what exists in the result files. Missing files, empty files, or missing columns are displayed explicitly and should not be converted into numerical claims.
#
# ## Recommended figures for thesis
# - `study_regime_BTCUSDT_15m_quantile_close_by_regime`
# - `study_regime_BTCUSDT_15m_hmm_close_by_regime` when HMM labels are available
# - `study_regime_BTCUSDT_15m_quantile_transition_heatmap`
# - `study_regime_duration_distribution_15m`
